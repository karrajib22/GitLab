# %%
# %config IPCompleter.greedy = True
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv("datasets/avocado.csv")
df.set_index('Date', inplace = True)
df.sort_index(inplace=True)
df = df.copy()[df['type'].str.upper() == ("ORGANIC")]
df
# Out:
#             Unnamed: 0         ...                        region
# Date                           ...
# 2015-01-04          51         ...                     Southeast
# 2015-01-04          51         ...                       Chicago
# 2015-01-04          51         ...            HarrisburgScranton
# 2015-01-04          51         ...                         Boise
# 2015-01-04          51         ...                      LasVegas
# 2015-01-04          51         ...             MiamiFtLauderdale
# 2015-01-04          51         ...                       StLouis
# 2015-01-04          51         ...                    Pittsburgh
# 2015-01-04          51         ...                      Syracuse
# 2015-01-04          51         ...                      Midsouth
# 2015-01-04          51         ...                        Albany
# 2015-01-04          51         ...                       Houston
# 2015-01-04          51         ...              BuffaloRochester
# 2015-01-04          51         ...                   GrandRapids
# 2015-01-04          51         ...                        Denver
# 2015-01-04          51         ...                      SanDiego
# 2015-01-04          51         ...           BaltimoreWashington
# 2015-01-04          51         ...                 DallasFtWorth
# 2015-01-04          51         ...                       Atlanta
# 2015-01-04          51         ...               RichmondNorfolk
# 2015-01-04          51         ...                    Louisville
# 2015-01-04          51         ...             RaleighGreensboro
# 2015-01-04          51         ...                       Spokane
# 2015-01-04          51         ...                       NewYork
# 2015-01-04          51         ...                  SouthCentral
# 2015-01-04          51         ...                       Roanoke
# 2015-01-04          51         ...                  Indianapolis
# 2015-01-04          51         ...                  Jacksonville
# 2015-01-04          51         ...                  Philadelphia
# 2015-01-04          51         ...                 PhoenixTucson
# ...                ...         ...                           ...
# 2018-03-25           0         ...                       Roanoke
# 2018-03-25           0         ...                 SouthCarolina
# 2018-03-25           0         ...           BaltimoreWashington
# 2018-03-25           0         ...                    LosAngeles
# 2018-03-25           0         ...                      Midsouth
# 2018-03-25           0         ...                       Seattle
# 2018-03-25           0         ...                    Sacramento
# 2018-03-25           0         ...                       Atlanta
# 2018-03-25           0         ...                    Louisville
# 2018-03-25           0         ...                  SanFrancisco
# 2018-03-25           0         ...                        Albany
# 2018-03-25           0         ...                      SanDiego
# 2018-03-25           0         ...                     Nashville
# 2018-03-25           0         ...                      LasVegas
# 2018-03-25           0         ...                       Houston
# 2018-03-25           0         ...                      Portland
# 2018-03-25           0         ...                       StLouis
# 2018-03-25           0         ...                     Charlotte
# 2018-03-25           0         ...                       NewYork
# 2018-03-25           0         ...                       Spokane
# 2018-03-25           0         ...             RaleighGreensboro
# 2018-03-25           0         ...                  Indianapolis
# 2018-03-25           0         ...              BuffaloRochester
# 2018-03-25           0         ...              NewOrleansMobile
# 2018-03-25           0         ...                     Southeast
# 2018-03-25           0         ...                  Jacksonville
# 2018-03-25           0         ...               RichmondNorfolk
# 2018-03-25           0         ...                        Boston
# 2018-03-25           0         ...                  SouthCentral
# 2018-03-25           0         ...                    California
#
# [9123 rows x 13 columns]

# %%
# df["Date"]=pd.to_datetime(df["Date"])
albany_df = df[df["region"]=="Albany"]
# albany_df.set_index("Date", inplace = True)
albany_df["AveragePrice"].plot()

# %%
print(albany_df.index)
albany_df.sort_index(inplace=True)
print(albany_df.index)
# Out:
# Index(['2015-01-04', '2015-01-11', '2015-01-18', '2015-01-25', '2015-02-01',
#        '2015-02-08', '2015-02-15', '2015-02-22', '2015-03-01', '2015-03-08',
#        ...
#        '2018-01-21', '2018-01-28', '2018-02-04', '2018-02-11', '2018-02-18',
#        '2018-02-25', '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25'],
#       dtype='object', name='Date', length=169)
# Index(['2015-01-04', '2015-01-11', '2015-01-18', '2015-01-25', '2015-02-01',
#        '2015-02-08', '2015-02-15', '2015-02-22', '2015-03-01', '2015-03-08',
#        ...
#        '2018-01-21', '2018-01-28', '2018-02-04', '2018-02-11', '2018-02-18',
#        '2018-02-25', '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25'],
#       dtype='object', name='Date', length=169)

# %%
print(albany_df["AveragePrice"].rolling(25).mean().plot())
albany_df["price25ma"]=albany_df["AveragePrice"].rolling(25).mean()
print(albany_df.head(26))
print(albany_df.tail(3))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             Unnamed: 0  AveragePrice    ...      region  price25ma
# Date                                    ...
# 2015-01-04          51          1.79    ...      Albany        NaN
# 2015-01-11          50          1.77    ...      Albany        NaN
# 2015-01-18          49          1.93    ...      Albany        NaN
# 2015-01-25          48          1.89    ...      Albany        NaN
# 2015-02-01          47          1.83    ...      Albany        NaN
# 2015-02-08          46          1.59    ...      Albany        NaN
# 2015-02-15          45          1.81    ...      Albany        NaN
# 2015-02-22          44          1.82    ...      Albany        NaN
# 2015-03-01          43          1.76    ...      Albany        NaN
# 2015-03-08          42          1.79    ...      Albany        NaN
# 2015-03-15          41          1.79    ...      Albany        NaN
# 2015-03-22          40          1.86    ...      Albany        NaN
# 2015-03-29          39          1.93    ...      Albany        NaN
# 2015-04-05          38          1.93    ...      Albany        NaN
# 2015-04-12          37          1.76    ...      Albany        NaN
# 2015-04-19          36          1.96    ...      Albany        NaN
# 2015-04-26          35          1.90    ...      Albany        NaN
# 2015-05-03          34          2.03    ...      Albany        NaN
# 2015-05-10          33          1.98    ...      Albany        NaN
# 2015-05-17          32          1.87    ...      Albany        NaN
# 2015-05-24          31          1.93    ...      Albany        NaN
# 2015-05-31          30          1.90    ...      Albany        NaN
# 2015-06-07          29          1.93    ...      Albany        NaN
# 2015-06-14          28          2.03    ...      Albany        NaN
# 2015-06-21          27          2.09    ...      Albany     1.8748
# 2015-06-28          26          2.02    ...      Albany     1.8840
#
# [26 rows x 14 columns]
#             Unnamed: 0  AveragePrice    ...      region  price25ma
# Date                                    ...
# 2018-03-11           2          1.68    ...      Albany     1.5044
# 2018-03-18           1          1.66    ...      Albany     1.5140
# 2018-03-25           0          1.71    ...      Albany     1.5188
#
# [3 rows x 14 columns]

# %%
# Using copy
albany_df = df.copy()[df["region"]=="Albany"]
# albany_df.set_index("Date", inplace = True)
albany_df["AveragePrice"].plot()

# %%
print(albany_df.index)
albany_df.sort_index(inplace=True)
print(albany_df.index)
# Warning is gone away
# Out:
# Index(['2015-01-04', '2015-01-11', '2015-01-18', '2015-01-25', '2015-02-01',
#        '2015-02-08', '2015-02-15', '2015-02-22', '2015-03-01', '2015-03-08',
#        ...
#        '2018-01-21', '2018-01-28', '2018-02-04', '2018-02-11', '2018-02-18',
#        '2018-02-25', '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25'],
#       dtype='object', name='Date', length=169)
# Index(['2015-01-04', '2015-01-11', '2015-01-18', '2015-01-25', '2015-02-01',
#        '2015-02-08', '2015-02-15', '2015-02-22', '2015-03-01', '2015-03-08',
#        ...
#        '2018-01-21', '2018-01-28', '2018-02-04', '2018-02-11', '2018-02-18',
#        '2018-02-25', '2018-03-04', '2018-03-11', '2018-03-18', '2018-03-25'],
#       dtype='object', name='Date', length=169)

# %%
print(albany_df["AveragePrice"].rolling(25).mean().plot())
albany_df["price25ma"]=albany_df["AveragePrice"].rolling(25).mean()
print(albany_df.head(26))
print(albany_df.tail(3))
# Warning is gone
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#             Unnamed: 0  AveragePrice    ...      region  price25ma
# Date                                    ...
# 2015-01-04          51          1.79    ...      Albany        NaN
# 2015-01-11          50          1.77    ...      Albany        NaN
# 2015-01-18          49          1.93    ...      Albany        NaN
# 2015-01-25          48          1.89    ...      Albany        NaN
# 2015-02-01          47          1.83    ...      Albany        NaN
# 2015-02-08          46          1.59    ...      Albany        NaN
# 2015-02-15          45          1.81    ...      Albany        NaN
# 2015-02-22          44          1.82    ...      Albany        NaN
# 2015-03-01          43          1.76    ...      Albany        NaN
# 2015-03-08          42          1.79    ...      Albany        NaN
# 2015-03-15          41          1.79    ...      Albany        NaN
# 2015-03-22          40          1.86    ...      Albany        NaN
# 2015-03-29          39          1.93    ...      Albany        NaN
# 2015-04-05          38          1.93    ...      Albany        NaN
# 2015-04-12          37          1.76    ...      Albany        NaN
# 2015-04-19          36          1.96    ...      Albany        NaN
# 2015-04-26          35          1.90    ...      Albany        NaN
# 2015-05-03          34          2.03    ...      Albany        NaN
# 2015-05-10          33          1.98    ...      Albany        NaN
# 2015-05-17          32          1.87    ...      Albany        NaN
# 2015-05-24          31          1.93    ...      Albany        NaN
# 2015-05-31          30          1.90    ...      Albany        NaN
# 2015-06-07          29          1.93    ...      Albany        NaN
# 2015-06-14          28          2.03    ...      Albany        NaN
# 2015-06-21          27          2.09    ...      Albany     1.8748
# 2015-06-28          26          2.02    ...      Albany     1.8840
#
# [26 rows x 14 columns]
#             Unnamed: 0  AveragePrice    ...      region  price25ma
# Date                                    ...
# 2018-03-11           2          1.68    ...      Albany     1.5044
# 2018-03-18           1          1.66    ...      Albany     1.5140
# 2018-03-25           0          1.71    ...      Albany     1.5188
#
# [3 rows x 14 columns]

# %%
# What if plot the above chart for all regions
print(df["region"].values )
# prob: we need unique values from the list of duplicate values

print(df["region"].unique())
print(df["type"].unique())
# Out:
# ['Southeast' 'Chicago' 'HarrisburgScranton' ... 'Boston' 'SouthCentral'
#  'California']
# ['Southeast' 'Chicago' 'HarrisburgScranton' 'Boise' 'LasVegas'
#  'MiamiFtLauderdale' 'StLouis' 'Pittsburgh' 'Syracuse' 'Midsouth' 'Albany'
#  'Houston' 'BuffaloRochester' 'GrandRapids' 'Denver' 'SanDiego'
#  'BaltimoreWashington' 'DallasFtWorth' 'Atlanta' 'RichmondNorfolk'
#  'Louisville' 'RaleighGreensboro' 'Spokane' 'NewYork' 'SouthCentral'
#  'Roanoke' 'Indianapolis' 'Jacksonville' 'Philadelphia' 'PhoenixTucson'
#  'GreatLakes' 'LosAngeles' 'NewOrleansMobile' 'Sacramento' 'Columbus'
#  'Charlotte' 'HartfordSpringfield' 'Tampa' 'TotalUS' 'Northeast'
#  'SouthCarolina' 'Orlando' 'CincinnatiDayton' 'Detroit' 'SanFrancisco'
#  'Portland' 'West' 'Nashville' 'WestTexNewMexico' 'Seattle' 'Plains'
#  'California' 'Boston' 'NorthernNewEngland']
# ['organic']

# %%
'''
creatig a new dataframe where all regions will be a column each, 
Date will be index and rows will be values of price25ma
'''

graph_df = pd.DataFrame()

for i in df['region'].unique():
    print(i)
    region_df = df.copy()[df['region']==i]
    region_df.sort_index(inplace=True)
    region_df[f"{i}_price25ma"]=region_df["AveragePrice"].rolling(25).mean()
    
#     graph_df = graph_df.join(region_df[f"{i}_price25ma"])
    
    if graph_df.empty:
        graph_df = region_df[[f"{i}_price25ma"]]
    else:
        graph_df = graph_df.join(region_df[f"{i}_price25ma"])
# Out:
# Southeast
# Chicago
# HarrisburgScranton
# Boise
# LasVegas
# MiamiFtLauderdale
# StLouis
# Pittsburgh
# Syracuse
# Midsouth
# Albany
# Houston
# BuffaloRochester
# GrandRapids
# Denver
# SanDiego
# BaltimoreWashington
# DallasFtWorth
# Atlanta
# RichmondNorfolk
# Louisville
# RaleighGreensboro
# Spokane
# NewYork
# SouthCentral
# Roanoke
# Indianapolis
# Jacksonville
# Philadelphia
# PhoenixTucson
# GreatLakes
# LosAngeles
# NewOrleansMobile
# Sacramento
# Columbus
# Charlotte
# HartfordSpringfield
# Tampa
# TotalUS
# Northeast
# SouthCarolina
# Orlando
# CincinnatiDayton
# Detroit
# SanFrancisco
# Portland
# West
# Nashville
# WestTexNewMexico
# Seattle
# Plains
# California
# Boston
# NorthernNewEngland

# %%
graph_df = graph_df.copy().dropna()

# %%
graph_df.head(5)
# Out:
#             Southeast_price25ma              ...               NorthernNewEngland_price25ma
# Date                                         ...
# 2015-06-21               1.7100              ...                                     1.8848
# 2015-06-28               1.7096              ...                                     1.8896
# 2015-07-05               1.7052              ...                                     1.8924
# 2015-07-12               1.7024              ...                                     1.8952
# 2015-07-19               1.6912              ...                                     1.8976
#
# [5 rows x 54 columns]

# %%
graph_df.plot()

# %%
graph_df.plot(figsize=(10,8), legend=False)
